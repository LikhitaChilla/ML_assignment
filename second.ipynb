# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('StudentPerformanceFactors.csv')

# %%
for i in df.columns:
   if df[i].dtypes=='object':
      print(df[i].unique())
# Out:
# ['Low' 'Medium' 'High']
# ['High' 'Medium' 'Low']
# ['No' 'Yes']
# ['Low' 'Medium' 'High']
# ['Yes' 'No']
# ['Low' 'Medium' 'High']
# ['Medium' 'High' 'Low' nan]
# ['Public' 'Private']
# ['Positive' 'Negative' 'Neutral']
# ['No' 'Yes']
# ['High School' 'College' 'Postgraduate' nan]
# ['Near' 'Moderate' 'Far' nan]
# ['Male' 'Female']

# %%
df['Parental_Involvement'].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
cat_col=[]
for i in df.columns:
    if df[i].dtypes=='object':
        cat_col.append(i)
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in cat_col:
    df[col] = le.fit_transform(df[col])
df.head()
# Out:
#    Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0             23          84                     1                    0
# 1             19          64                     1                    2
# 2             24          98                     2                    2
# 3             29          89                     1                    2
# 4             19          92                     2                    2
#
#    Extracurricular_Activities  Sleep_Hours  Previous_Scores  Motivation_Level  \
# 0                           0            7               73                 1
# 1                           0            8               59                 1
# 2                           1            7               91                 2
# 3                           1            8               98                 2
# 4                           1            6               65                 2
#
# ...

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
corr_mat=df.corr()

# %%
(corr_mat)
# Out:
#                             Hours_Studied  Attendance  Parental_Involvement  \
# Hours_Studied                    1.000000   -0.009908              0.007207
# Attendance                      -0.009908    1.000000             -0.004940
# Parental_Involvement             0.007207   -0.004940              1.000000
# Access_to_Resources             -0.007909    0.000862              0.010476
# Extracurricular_Activities      -0.006017   -0.002222              0.022225
# Sleep_Hours                      0.010977   -0.015918              0.001280
# Previous_Scores                  0.024846   -0.020186              0.005094
# Motivation_Level                 0.022092    0.013098             -0.013449
# Internet_Access                  0.005038   -0.018318              0.001863
# Tutoring_Sessions               -0.014282    0.014324             -0.007655
# Family_Income                    0.010025   -0.008097              0.005080
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x=df.drop('Exam_Score',axis=1)
y=df['Exam_Score']

# %%
x.head()
# Out:
#    Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0             23          84                     1                    0
# 1             19          64                     1                    2
# 2             24          98                     2                    2
# 3             29          89                     1                    2
# 4             19          92                     2                    2
#
#    Extracurricular_Activities  Sleep_Hours  Previous_Scores  Motivation_Level  \
# 0                           0            7               73                 1
# 1                           0            8               59                 1
# 2                           1            7               91                 2
# 3                           1            8               98                 2
# 4                           1            6               65                 2
#
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
mse=mean_absolute_error(y_pred,y_test)

# %%
mse
# Out:
# 1.0203213849038473

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor(max_depth=3)

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
y_pre=dt.predict(x_test)

# %%
ms=mean_absolute_error(y_pred,y_test)

# %%
ms
# Out:
# 1.0203213849038473

# %%
from sklearn.metrics import r2_score
h=r2_score(y_test,y_pred)

# %%
h
# Out:
# 0.6886467116230378

# %%
feature_names=x_train.columns.to_list()

# %%
import pickle
with open('linear_regression_modell.pkl','wb') as file:
    pickle.dump((lr,feature_names),file)

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
# import streamlit as st
# import pickle
# import numpy as np

# # Load the pickled model
# with open('linear_regression_model.pkl', 'rb') as model_file:
#     model = pickle.load(model_file)

# # Function to make predictions
# def predict(input_data):
#     # Convert input data to numpy array and reshape if necessary
#     input_array = np.array(input_data).reshape(1, -1)
#     return model.predict(input_array)

# # Streamlit app
# st.title('Model Deployment with Streamlit')
# # Input form
# st.sidebar.header('Input Parameters')
# param1 = st.sidebar.number_input('Hours_Studied', value=0)
# param2 = st.sidebar.number_input('Attendance', value=0)
# param3= st.text_input('Parental_Involvement',placeholder='Low or medium or high' )
# param4 = st.text_input('Access_to_Resources', placeholder='Low or medium or high')
# param5 = st.text_input('Extracurricular_Activities',placeholder='No or Yes')
# param6 = st.sidebar.number_input('Sleep_Hours', value=0)
# param7 = st.sidebar.number_input('Previous_Scores', value=0)
# param8 = st.text_input('Motivation_Level',placeholder='Low or medium or high')
# param9 = st.text_input('Internet_Access',placeholder='No or Yes')
# param10 = st.sidebar.number_input('Tutoring_Sessions', value=0)
# param11 = st.text_input('Family_Income',placeholder='Low or medium or high')
# param12 = st.text_input('Teacher_Quality',placeholder='Low or medium or high')
# param13 = st.text_input('School_Type', placeholder='Public or Private')
# param14 = st.text_input('Peer_Influence',placeholder='Positive or Negative or Neutral')
# param15 = st.sidebar.number_input('Physical_Activity',value=0)
# param16 = st.text_input('Learning_Disabilities', placeholder='No or Yes')
# param17 = st.text_input('Parental_Education_Level',placeholder='High School or College or Postgraduate')
# param18 = st.text_input('Distance_from_Home',placeholder='Near or Moderate or Far')
# param19 = st.text_input('Gender',placeholder='Male or Female')
# new_frame=pd.DataFrame([param1, param2, param3,param4, param5, param6,param7, param8, param9,param10, param11, param12,param13, param14, param15,param16, param17, param18,param19],columns=['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score']
# )
# # Create input data list
# input_data = [param1, param2, param3,param4, param5, param6,param7, param8, param9,param10, param11, param12,param13, param14, param15,param16, param17, param18,param19]

# # Make prediction on button click
# if st.button('Predict'):
#     prediction = predict(input_data)
#     st.write(f'Prediction: {prediction[0]}')

# # Optional: Display the model's details
# if st.checkbox('Show Model Info'):
#     st.write(model)

# %%
/
# Out:
# ()

# %%
# features={
#     'Parental_Involvement':['Low','medium','high'],
#     'Access_to_Resources':['Low','medium','high'],
#     'Extracurricular_Activities':['No','Yes'],
#     'Motivation_Level':['Low','medium','high'],
#     'Internet_Access':['No','Yes'],
#     'Family_Income':['Low','medium','high'],
#     'Teacher_Quality':['Low','medium','high'],
#     'School_Type':['Public','Private'],
#     'Peer_Influence':['Positive','Negative','Neutral'],
#     'Learning_Disabilities':['No','Yes'],
#     'Parental_Education_Level':['High School','College','Postgraduate'],
#     'Distance_from_Home':['Near','Moderate','Far'],
#     'Gender':['Male','Female']
# }

# %%
# selected_features={}
# for feature,options in features.items():
#     st.write(f'Select options for {feature}: ')
#     selected_features[feature]=[]
#     for opt in options:
#         if st.checkbox(f'{opt} for {feature}'):
#             selected_features[feature].append(opt)

# %%
/
# Out:
# ()

# %%
# se
